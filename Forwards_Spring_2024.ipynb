# %%
#**************************************
# Name: Jonah Zembower
# Date: June 28, 2024
# Focusing in on positional differences
#**************************************

# %%
# import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing file paths
alessandro_sanchez = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Alessandro Sanchez/Alessandro_Sanchez_Spring_2024.csv')
andrew_koma = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Andrew Koma/Andrew_Koma_Spring_2024.csv')
brice_gandhi = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Brice Gandhi/Brice_Gandhi_Spring_2024.csv')
james_aubrey = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/James Aubrey/James_Aubrey_Spring_2024.csv')
keegan_amos = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Keegan Amos/Keegan_Amos_Spring_2024.csv')
logen_mackey = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Logen Mackey/Logen_Mackey_Spring_2024.csv')
mason_fabean = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Mason Fabean/Mason_Fabean_Spring_2024.csv')
tristan_wilson = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Tristan Wilson/Tristan_Wilson_Spring_2024.csv')

# %%
# Calculate the daily average heart rates for each person
alessandro_daily_avg = alessandro_sanchez.mean(axis=0)
andrew_daily_avg = andrew_koma.mean(axis=0)
brice_daily_avg = brice_gandhi.mean(axis=0)
james_daily_avg = james_aubrey.mean(axis=0)
keegan_daily_avg = keegan_amos.mean(axis=0)
logen_daily_avg = logen_mackey.mean(axis=0)
mason_daily_avg = mason_fabean.mean(axis=0)
tristan_daily_avg = tristan_wilson.mean(axis=0)


# Convert the indices to datetime for plotting
alessandro_daily_avg.index = pd.to_datetime(alessandro_daily_avg.index)
andrew_daily_avg.index = pd.to_datetime(andrew_daily_avg.index)
brice_daily_avg.index = pd.to_datetime(brice_daily_avg.index)
james_daily_avg.index = pd.to_datetime(james_daily_avg.index)
keegan_daily_avg.index = pd.to_datetime(keegan_daily_avg.index)
logen_daily_avg.index = pd.to_datetime(logen_daily_avg.index)
mason_daily_avg.index = pd.to_datetime(mason_daily_avg.index)
tristan_daily_avg.index = pd.to_datetime(tristan_daily_avg.index)


# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Alessandro': alessandro_daily_avg,
    'Andrew': andrew_daily_avg,
    'Brice': brice_daily_avg,
    'James': james_daily_avg,
    'Keegan': keegan_daily_avg,
    'Logen': logen_daily_avg,
    'Mason': mason_daily_avg,
    'Tristan': tristan_daily_avg
})

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Calculate the daily average heart rates for each person
alessandro_daily_avg = alessandro_sanchez.mean(axis=0)
andrew_daily_avg = andrew_koma.mean(axis=0)
brice_daily_avg = brice_gandhi.mean(axis=0)
james_daily_avg = james_aubrey.mean(axis=0)
keegan_daily_avg = keegan_amos.mean(axis=0)
logen_daily_avg = logen_mackey.mean(axis=0)
mason_daily_avg = mason_fabean.mean(axis=0)
tristan_daily_avg = tristan_wilson.mean(axis=0)


# Convert the indices to datetime for plotting
alessandro_daily_avg.index = pd.to_datetime(alessandro_daily_avg.index)
andrew_daily_avg.index = pd.to_datetime(andrew_daily_avg.index)
brice_daily_avg.index = pd.to_datetime(brice_daily_avg.index)
james_daily_avg.index = pd.to_datetime(james_daily_avg.index)
keegan_daily_avg.index = pd.to_datetime(keegan_daily_avg.index)
logen_daily_avg.index = pd.to_datetime(logen_daily_avg.index)
mason_daily_avg.index = pd.to_datetime(mason_daily_avg.index)
tristan_daily_avg.index = pd.to_datetime(tristan_daily_avg.index)


# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Alessandro': alessandro_daily_avg,
    'Andrew': andrew_daily_avg,
    'Brice': brice_daily_avg,
    'James': james_daily_avg,
    'Keegan': keegan_daily_avg,
    'Logen': logen_daily_avg,
    'Mason': mason_daily_avg,
    'Tristan': tristan_daily_avg
})

# Calculate the overall average across all players
comparison_df['Average'] = comparison_df.mean(axis=1)

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

# Highlight the average line
plt.plot(comparison_df.index, comparison_df['Average'], label='Average', color='black', linestyle='--', linewidth=2)

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Compute and output the overall average heart rate across all sessions for each player
alessandro_overall_avg = alessandro_daily_avg.mean()
andrew_overall_avg = andrew_daily_avg.mean()
brice_overall_avg = brice_daily_avg.mean()
james_overall_avg = james_daily_avg.mean()
keegan_overall_avg = keegan_daily_avg.mean()
logen_overall_avg = logen_daily_avg.mean()
mason_overall_avg = mason_daily_avg.mean()
tristan_overall_avg = tristan_daily_avg.mean()

# Compute the overall average heart rate across all players
overall_avg_all_players = comparison_df['Average'].mean()

# Output the results
print(f"Overall average heart rate for Alessandro: {alessandro_overall_avg:.2f}")
print(f"Overall average heart rate for Andrew: {andrew_overall_avg:.2f}")
print(f"Overall average heart rate for Brice: {brice_overall_avg:.2f}")
print(f"Overall average heart rate for James: {james_overall_avg:.2f}")
print(f"Overall average heart rate for Keegan: {keegan_overall_avg:.2f}")
print(f"Overall average heart rate for Logen: {logen_overall_avg:.2f}")
print(f"Overall average heart rate for Mason: {mason_overall_avg:.2f}")
print(f"Overall average heart rate for Tristan: {tristan_overall_avg:.2f}")
print(f"Overall average heart rate across all players: {overall_avg_all_players:.2f}")
# Out:
# Overall average heart rate for Alessandro: 128.35
# Overall average heart rate for Andrew: 140.48
# Overall average heart rate for Brice: 132.13
# Overall average heart rate for James: 144.36
# Overall average heart rate for Keegan: 147.08
# Overall average heart rate for Logen: 150.78
# Overall average heart rate for Mason: 145.85
# Overall average heart rate for Tristan: 128.75
# Overall average heart rate across all players: 139.62

# %%
# Convert the index to datetime for resampling
comparison_df.index = pd.to_datetime(comparison_df.index)

# Resample the data by week and calculate the weekly average heart rate for each individual
weekly_avg_df = comparison_df.resample('W').mean()

# Plot the weekly average heart rates
plt.figure(figsize=(14, 8))

for column in weekly_avg_df.columns:
    plt.plot(weekly_avg_df.index, weekly_avg_df[column], label=column, marker='o')

plt.xlabel('Week')
plt.ylabel('Average Heart Rate')
plt.title('Weekly Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Reset index to get dates in the DataFrame
comparison_df.reset_index(inplace=True)

# Convert DataFrame from wide to long format for easier plotting
long_df = comparison_df.melt(id_vars='index', var_name='Individual', value_name='Heart Rate')

# Add a column for week
long_df['Week'] = pd.to_datetime(long_df['index']).dt.to_period('W')

# Plot box plots
plt.figure(figsize=(16, 10))
sns.boxplot(x='Week', y='Heart Rate', hue='Individual', data=long_df, palette='Set3')
plt.title('Weekly Distribution of Heart Rates')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Generate heatmaps to visualize the intensity of heart rates over time

# Set the index back to the original datetime index
comparison_df.set_index('index', inplace=True)

# Plot heatmaps
plt.figure(figsize=(16, 12))

sns.heatmap(comparison_df.T, cmap='coolwarm', cbar=True, linewidths=.5)
plt.title('Heatmap of Heart Rate Intensities Over Time')
plt.xlabel('Date')
plt.ylabel('Individual')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plot a correlation matrix to explore relationships between heart rates of different individuals
correlation_matrix = comparison_df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Heart Rates Between Individuals')
plt.tight_layout()
plt.show()

# %%
# Calculate the daily average heart rates for each person
alessandro_daily_max = alessandro_sanchez.max(axis=0)
andrew_daily_max = andrew_koma.max(axis=0)
brice_daily_max = brice_gandhi.max(axis=0)
james_daily_max = james_aubrey.max(axis=0)
keegan_daily_max = keegan_amos.max(axis=0)
logen_daily_max = logen_mackey.max(axis=0)
mason_daily_max = mason_fabean.max(axis=0)
tristan_daily_max = tristan_wilson.max(axis=0)


# Convert the indices to datetime for plotting
alessandro_daily_max.index = pd.to_datetime(alessandro_daily_max.index)
andrew_daily_max.index = pd.to_datetime(andrew_daily_max.index)
brice_daily_max.index = pd.to_datetime(brice_daily_max.index)
james_daily_max.index = pd.to_datetime(james_daily_max.index)
keegan_daily_max.index = pd.to_datetime(keegan_daily_max.index)
logen_daily_max.index = pd.to_datetime(logen_daily_max.index)
mason_daily_max.index = pd.to_datetime(mason_daily_max.index)
tristan_daily_max.index = pd.to_datetime(tristan_daily_max.index)


# Create a DataFrame for easier comparison
comparison_df_max = pd.DataFrame({
    'Alessandro': alessandro_daily_max,
    'Andrew': andrew_daily_max,
    'Brice': brice_daily_max,
    'James': james_daily_max,
    'Keegan': keegan_daily_max,
    'Logen': logen_daily_max,
    'Mason': mason_daily_max,
    'Tristan': tristan_daily_max
})

# Plot the maximum heart rate for each day
plt.figure(figsize=(14, 8))
for column in comparison_df_max.columns:
    plt.plot(comparison_df_max.index, comparison_df_max[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Maximum Heart Rate')
plt.title('Maximum Heart Rate for Each Day Across All Individuals')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# Now I want to look at the moments leading up to a game and how players are reacting in their heart rate.
#
# We had games on:
# - March 16 Game against Missisauga
# - March 24 Game against Lancaster F.C.
# - April 7 Game against Wheeling University
# - April 13 Tournament against Juniata, Mount Aloysius, then St. Vincent

# %%
missisauga_alessandro = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Alessandro Sanchez/Alessandro_Sanchez_2024-03-16_15-24-13.CSV'
missisauga_andrew = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Andrew Koma/Andrew_Koma_2024-03-16_15-24-13.CSV'
missisauga_brice = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Brice Gandhi/Brice_Gandhi_2024-03-16_15-24-13.CSV'
missisauga_james = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/James Aubrey/James_Aubrey_2024-03-16_15-24-16.CSV'
missisauga_keegan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Keegan Amos/Keegan_Amos_2024-03-16_15-24-13.CSV'
missisauga_mason = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Mason Fabean/Mason_Fabean_2024-03-16_15-24-14.CSV'
missisauga_tristan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Tristan Wilson/Tristan_Wilson_2024-03-16_15-24-13.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(missisauga_alessandro, skiprows=2)
df2 = pd.read_csv(missisauga_andrew, skiprows=2)
df3 = pd.read_csv(missisauga_brice, skiprows=2)
df4 = pd.read_csv(missisauga_james, skiprows=2)
df5 = pd.read_csv(missisauga_keegan, skiprows=2)
df6 = pd.read_csv(missisauga_mason, skiprows=2)
df7 = pd.read_csv(missisauga_tristan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()
df7.columns = df7.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
df7.head(), df7.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       120           NaN            NaN      NaN
#  1          NaN  00:00:02       119           NaN            NaN      NaN
#  2          NaN  00:00:04       118           NaN            NaN      NaN
#  3          NaN  00:00:06       118           NaN            NaN      NaN
#  4          NaN  00:00:08       115           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Missisauga Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Alessandro Sanchez",
    "Andrew Koma",
    "Brice Gandhi"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Missisauga Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df4, df5, df6, df7]
titles = [
    "James Aubrey",
    "Keegan Amos",
    "Mason Fabean",
    "Tristan Wilson"
]
plot_multiple_time_series(dfs, titles)

# %%
lancaster_andrew = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Andrew Koma/Andrew_Koma_2024-03-24_14-27-24.CSV'
lancaster_brice = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Brice Gandhi/Brice_Gandhi_2024-03-24_14-27-25.CSV'
lancaster_james = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/James Aubrey/James_Aubrey_2024-03-24_14-27-33.CSV'
lancaster_logen = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Logen Mackey/Logen_+Mackey_2024-03-24_17-07-16.CSV'
lancaster_mason = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Mason Fabean/Mason_Fabean_2024-03-24_17-16-54.CSV'
lancaster_tristan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Tristan Wilson/Tristan_Wilson_2024-03-24_14-27-24.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(lancaster_andrew, skiprows=2)
df2 = pd.read_csv(lancaster_brice, skiprows=2)
df3 = pd.read_csv(lancaster_james, skiprows=2)
df4 = pd.read_csv(lancaster_logen, skiprows=2)
df5 = pd.read_csv(lancaster_mason, skiprows=2)
df6 = pd.read_csv(lancaster_tristan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       124           NaN            NaN      NaN
#  1          NaN  00:00:02       122           NaN            NaN      NaN
#  2          NaN  00:00:04       120           NaN            NaN      NaN
#  3          NaN  00:00:06       116           NaN            NaN      NaN
#  4          NaN  00:00:08       115           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Lancaster F.C. Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Andrew Koma",
    "Brice Gandhi",
    "James Aubrey"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Lancaster F.C. Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df4, df5, df6]
titles = [
    "Logen Mackey",
    "Mason Fabean",
    "Tristan Wilson"
]
plot_multiple_time_series(dfs, titles)

# %%
wheeling_alessandro = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Alessandro Sanchez/Alessandro_Sanchez_2024-04-07_14-54-19.CSV'
wheeling_andrew = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Andrew Koma/Andrew_Koma_2024-04-07_14-54-38.CSV'
wheeling_brice = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Brice Gandhi/Brice_Gandhi_2024-04-07_16-09-39.CSV'
wheeling_james = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/James Aubrey/James_Aubrey_2024-04-07_16-03-33.CSV'
wheeling_keegan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Keegan Amos/Keegan_Amos_2024-04-07_16-05-51.CSV'
wheeling_logen = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Logen Mackey/Logen_+Mackey_2024-04-07_14-54-18.CSV'
wheeling_mason = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Mason Fabean/Mason_Fabean_2024-04-07_14-54-45.CSV'
wheeling_tristan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Tristan Wilson/Tristan_Wilson_2024-04-07_15-19-37.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(wheeling_alessandro, skiprows=2)
df2 = pd.read_csv(wheeling_andrew, skiprows=2)
df3 = pd.read_csv(wheeling_brice, skiprows=2)
df4 = pd.read_csv(wheeling_james, skiprows=2)
df5 = pd.read_csv(wheeling_keegan, skiprows=2)
df6 = pd.read_csv(wheeling_logen, skiprows=2)
df7 = pd.read_csv(wheeling_mason, skiprows=2)
df8 = pd.read_csv(wheeling_tristan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()
df7.columns = df7.columns.str.strip()
df8.columns = df8.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
df7.head(), df7.columns
df8.head(), df8.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       101           NaN            NaN      NaN
#  1          NaN  00:00:02       102           NaN            NaN      NaN
#  2          NaN  00:00:04       102           NaN            NaN      NaN
#  3          NaN  00:00:06       100           NaN            NaN      NaN
#  4          NaN  00:00:08       100           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3, df4]
titles = [
    "Alessandro Sanchez",
    "Andrew Koma",
    "Brice Gandhi",
    "James Aubrey"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df5, df6, df7, df8]
titles = [
    "Keegan Amos",
    "Logen Mackey",
    "Mason Fabean",
    "Tristan Wilson"
]
plot_multiple_time_series(dfs, titles)

# %%
juniata_alessandro = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Alessandro Sanchez/Alessandro_Sanchez_2024-04-13_15-02-30.CSV'
juniata_andrew = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Andrew Koma/Andrew_Koma_2024-04-13_15-02-30.CSV'
juniata_mason = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Mason Fabean/Mason_Fabean_2024-04-13_15-02-30.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(juniata_alessandro, skiprows=2)
df2 = pd.read_csv(juniata_andrew, skiprows=2)
df3 = pd.read_csv(juniata_mason, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       102           NaN            NaN      NaN
#  1          NaN  00:00:02       106           NaN            NaN      NaN
#  2          NaN  00:00:04       111           NaN            NaN      NaN
#  3          NaN  00:00:06       113           NaN            NaN      NaN
#  4          NaN  00:00:08       118           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Juniata Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Alessandro Sanchez",
    "Andrew Koma",
    "Mason Fabean"
]
plot_multiple_time_series(dfs, titles)

# %%
mount_aloysius_andrew = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Andrew Koma/Andrew_Koma_2024-04-13_16-35-57.CSV'
mount_aloysius_keegan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Keegan Amos/Keegan_Amos_2024-04-13_16-36-09.CSV'
mount_aloysius_logen = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Logen Mackey/Logen_+Mackey_2024-04-13_16-35-57.CSV'
mount_aloysius_mason = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Mason Fabean/Mason_Fabean_2024-04-13_16-35-57.CSV'
mount_aloysius_tristan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Tristan Wilson/Tristan_Wilson_2024-04-13_16-41-07.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(mount_aloysius_andrew, skiprows=2)
df2 = pd.read_csv(mount_aloysius_keegan, skiprows=2)
df3 = pd.read_csv(mount_aloysius_logen, skiprows=2)
df4 = pd.read_csv(mount_aloysius_mason, skiprows=2)
df5 = pd.read_csv(mount_aloysius_tristan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       167           NaN            NaN      NaN
#  1          NaN  00:00:02       167           NaN            NaN      NaN
#  2          NaN  00:00:04       167           NaN            NaN      NaN
#  3          NaN  00:00:06       167           NaN            NaN      NaN
#  4          NaN  00:00:08       166           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Mount Aloysius Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3, df4, df5]
titles = [
    "Andrew Koma",
    "Keegan Amos",
    "Logen Mackey",
    "Mason Fabean",
    "Tristan Wilson"
]
plot_multiple_time_series(dfs, titles)

# %%
saint_vincent_brice = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/Brice Gandhi/Brice_Gandhi_2024-04-13_17-44-45.CSV'
saint_vincent_james = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Forwards/James Aubrey/James_Aubrey_2024-04-13_17-44-45.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df2 = pd.read_csv(saint_vincent_brice, skiprows=2)
df3 = pd.read_csv(saint_vincent_james, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00         0           NaN            NaN      NaN
#  1          NaN  00:00:02         0           NaN            NaN      NaN
#  2          NaN  00:00:04         0           NaN            NaN      NaN
#  3          NaN  00:00:06         0           NaN            NaN      NaN
#  4          NaN  00:00:08         0           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Saint Vincent Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df2, df3]
titles = [
    "Brice Gandhi",
    "James Aubrey"
]
plot_multiple_time_series(dfs, titles)
