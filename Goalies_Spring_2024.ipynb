# %%
#**************************************
# Name: Jonah Zembower
# Date: June 28, 2024
# Focusing in on positional differences
#**************************************

# %%
# import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing file paths
aiden_hollander = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Aiden Hollander/Aiden_Hollander_Spring_2024.csv')
jonathan_leary = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Jonathan Leary/Jonathan_Leary_Spring_2024.csv')
jared_johnson = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Jared Johnson/Jared_Johnson_Spring_2024.csv')

# %%
# Calculate the daily average heart rates for each person
aiden_daily_avg = aiden_hollander.mean(axis=0)
jonathan_daily_avg = jonathan_leary.mean(axis=0)
jared_daily_avg = jared_johnson.mean(axis=0)



# Convert the indices to datetime for plotting
aiden_daily_avg.index = pd.to_datetime(aiden_daily_avg.index)
jonathan_daily_avg.index = pd.to_datetime(jonathan_daily_avg.index)
jared_daily_avg.index = pd.to_datetime(jared_daily_avg.index)



# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Aiden': aiden_daily_avg,
    'Jonathan': jonathan_daily_avg,
    'Jared': jared_daily_avg
})

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Calculate the daily average heart rates for each person
aiden_daily_avg = aiden_hollander.mean(axis=0)
jonathan_daily_avg = jonathan_leary.mean(axis=0)
jared_daily_avg = jared_johnson.mean(axis=0)



# Convert the indices to datetime for plotting
aiden_daily_avg.index = pd.to_datetime(aiden_daily_avg.index)
jonathan_daily_avg.index = pd.to_datetime(jonathan_daily_avg.index)
jared_daily_avg.index = pd.to_datetime(jared_daily_avg.index)



# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Aiden': aiden_daily_avg,
    'Jonathan': jonathan_daily_avg,
    'Jared': jared_daily_avg
})

# Calculate the overall average across all players
comparison_df['Average'] = comparison_df.mean(axis=1)

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

# Highlight the average line
plt.plot(comparison_df.index, comparison_df['Average'], label='Average', color='black', linestyle='--', linewidth=2)

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Compute and output the overall average heart rate across all sessions for each player
aiden_overall_avg = aiden_daily_avg.mean()
jonathan_overall_avg = jonathan_daily_avg.mean()
jared_overall_avg = jared_daily_avg.mean()

# Compute the overall average heart rate across all players
overall_avg_all_players = comparison_df['Average'].mean()

# Output the results
print(f"Overall average heart rate for Aiden: {aiden_overall_avg:.2f}")
print(f"Overall average heart rate for Jonathan: {jonathan_overall_avg:.2f}")
print(f"Overall average heart rate for Jared: {jared_overall_avg:.2f}")
print(f"Overall average heart rate across all players: {overall_avg_all_players:.2f}")
# Out:
# Overall average heart rate for Aiden: 127.70
# Overall average heart rate for Jonathan: 120.34
# Overall average heart rate for Jared: 140.49
# Overall average heart rate across all players: 128.35

# %%
# Convert the index to datetime for resampling
comparison_df.index = pd.to_datetime(comparison_df.index)

# Resample the data by week and calculate the weekly average heart rate for each individual
weekly_avg_df = comparison_df.resample('W').mean()

# Plot the weekly average heart rates
plt.figure(figsize=(14, 8))

for column in weekly_avg_df.columns:
    plt.plot(weekly_avg_df.index, weekly_avg_df[column], label=column, marker='o')

plt.xlabel('Week')
plt.ylabel('Average Heart Rate')
plt.title('Weekly Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Reset index to get dates in the DataFrame
comparison_df.reset_index(inplace=True)

# Convert DataFrame from wide to long format for easier plotting
long_df = comparison_df.melt(id_vars='index', var_name='Individual', value_name='Heart Rate')

# Add a column for week
long_df['Week'] = pd.to_datetime(long_df['index']).dt.to_period('W')

# Plot box plots
plt.figure(figsize=(16, 10))
sns.boxplot(x='Week', y='Heart Rate', hue='Individual', data=long_df, palette='Set3')
plt.title('Weekly Distribution of Heart Rates')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Generate heatmaps to visualize the intensity of heart rates over time

# Set the index back to the original datetime index
comparison_df.set_index('index', inplace=True)

# Plot heatmaps
plt.figure(figsize=(16, 12))

sns.heatmap(comparison_df.T, cmap='coolwarm', cbar=True, linewidths=.5)
plt.title('Heatmap of Heart Rate Intensities Over Time')
plt.xlabel('Date')
plt.ylabel('Individual')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plot a correlation matrix to explore relationships between heart rates of different individuals
correlation_matrix = comparison_df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Heart Rates Between Individuals')
plt.tight_layout()
plt.show()

# %%
# Calculate the daily average heart rates for each person
aiden_daily_max = aiden_hollander.max(axis=0)
jonathan_daily_max = jonathan_leary.max(axis=0)
jared_daily_max = jared_johnson.max(axis=0)



# Convert the indices to datetime for plotting
aiden_daily_max.index = pd.to_datetime(aiden_daily_max.index)
jonathan_daily_max.index = pd.to_datetime(jonathan_daily_max.index)
jared_daily_max.index = pd.to_datetime(jared_daily_max.index)



# Create a DataFrame for easier comparison
comparison_df_max = pd.DataFrame({
    'Aiden': aiden_daily_max,
    'Jonathan': jonathan_daily_max,
    'Jared': jared_daily_max
})

# Plot the maximum heart rate for each day
plt.figure(figsize=(14, 8))
for column in comparison_df_max.columns:
    plt.plot(comparison_df_max.index, comparison_df_max[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Maximum Heart Rate')
plt.title('Maximum Heart Rate for Each Day Across All Individuals')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# Now I want to look at the moments leading up to a game and how players are reacting in their heart rate.
#
# We had games on:
# - March 16 Game against Missisauga
# - March 24 Game against Lancaster F.C.
# - April 7 Game against Wheeling University
# - April 13 Tournament against Juniata, Mount Aloysius, then St. Vincent

# %%
missisauga_aiden = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Aiden Hollander/Aiden_Hollander_2024-03-16_15-24-14.CSV'
missisauga_jared = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Jared Johnson/Jared_Johnson_2024-03-16_15-24-13.CSV'
missisauga_jonathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Jonathan Leary/Jonathan+_Leary_2024-03-16_15-24-13.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(missisauga_aiden, skiprows=2)
df2 = pd.read_csv(missisauga_jared, skiprows=2)
df3 = pd.read_csv(missisauga_jonathan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00        61           NaN            NaN      NaN
#  1          NaN  00:00:02         0           NaN            NaN      NaN
#  2          NaN  00:00:04         0           NaN            NaN      NaN
#  3          NaN  00:00:06         0           NaN            NaN      NaN
#  4          NaN  00:00:08         0           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
#  2        NaN          NaN
#  3        NaN          NaN
#  4        NaN          NaN  ,
#  Index(['Sample rate', 'Time', 'HR (bpm)', 'Speed (mi/h)', 'Pace (min/mi)',
#         'Cadence', 'Altitude (ft)', 'Stride length (in)', 'Distances (ft)',
#         'Temperatures (F)', 'Power (W)', 'Unnamed: 11'],
#        dtype='object'))

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Missisauga Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Aiden Hollander",
    "Jared Johnson",
    "Jonathan Leary"
]
plot_multiple_time_series(dfs, titles)

# %%
lancaster_aiden = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Aiden Hollander/Aiden_Hollander_2024-03-24_14-27-27.CSV'
lancaster_jared = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Jared Johnson/Jared_Johnson_2024-03-24_14-27-28.CSV'
lancaster_jonathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Jonathan Leary/Jonathan+_Leary_2024-03-24_14-27-33.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(lancaster_aiden, skiprows=2)
df2 = pd.read_csv(lancaster_jared, skiprows=2)
df3 = pd.read_csv(lancaster_jonathan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00        79           NaN            NaN      NaN
#  1          NaN  00:00:02        79           NaN            NaN      NaN
#  2          NaN  00:00:04        79           NaN            NaN      NaN
#  3          NaN  00:00:06        79           NaN            NaN      NaN
#  4          NaN  00:00:08        79           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
#  2        NaN          NaN
#  3        NaN          NaN
#  4        NaN          NaN  ,
#  Index(['Sample rate', 'Time', 'HR (bpm)', 'Speed (mi/h)', 'Pace (min/mi)',
#         'Cadence', 'Altitude (ft)', 'Stride length (in)', 'Distances (ft)',
#         'Temperatures (F)', 'Power (W)', 'Unnamed: 11'],
#        dtype='object'))

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Lancaster F.C. Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Aiden Hollander",
    "Jared Johnson",
    "Jonathan Leary"
]
plot_multiple_time_series(dfs, titles)

# %%
wheeling_aiden = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Aiden Hollander/Aiden_Hollander_2024-04-07_14-54-16.CSV'
wheeling_jonathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Jonathan Leary/Jonathan+_Leary_2024-04-07_14-54-17.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(wheeling_aiden, skiprows=2)
df2 = pd.read_csv(wheeling_jonathan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00        92           NaN            NaN      NaN
#  1          NaN  00:00:02        92           NaN            NaN      NaN
#  2          NaN  00:00:04        92           NaN            NaN      NaN
#  3          NaN  00:00:06        92           NaN            NaN      NaN
#  4          NaN  00:00:08        92           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
#  2        NaN          NaN
#  3        NaN          NaN
#  4        NaN          NaN  ,
#  Index(['Sample rate', 'Time', 'HR (bpm)', 'Speed (mi/h)', 'Pace (min/mi)',
#         'Cadence', 'Altitude (ft)', 'Stride length (in)', 'Distances (ft)',
#         'Temperatures (F)', 'Power (W)', 'Unnamed: 11'],
#        dtype='object'))

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Aiden Hollander",
    "Jonathan Leary"
]
plot_multiple_time_series(dfs, titles)

# %%
juniata_aiden = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Aiden Hollander/Aiden_Hollander_2024-04-13_15-02-30.CSV'
juniata_jonathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Jonathan Leary/Jonathan+_Leary_2024-04-13_15-02-30.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df2 = pd.read_csv(juniata_aiden, skiprows=2)
df3 = pd.read_csv(juniata_jonathan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00        25           NaN            NaN      NaN
#  1          NaN  00:00:02        25           NaN            NaN      NaN
#  2          NaN  00:00:04        25           NaN            NaN      NaN
#  3          NaN  00:00:06        25           NaN            NaN      NaN
#  4          NaN  00:00:08        25           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
#  2        NaN          NaN
#  3        NaN          NaN
#  4        NaN          NaN  ,
#  Index(['Sample rate', 'Time', 'HR (bpm)', 'Speed (mi/h)', 'Pace (min/mi)',
#         'Cadence', 'Altitude (ft)', 'Stride length (in)', 'Distances (ft)',
#         'Temperatures (F)', 'Power (W)', 'Unnamed: 11'],
#        dtype='object'))

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Juniata Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df2, df3]
titles = [
    "Aiden Hollander",
    "Jonathan Leary"
]
plot_multiple_time_series(dfs, titles)

# %%
mount_aloysius_aiden = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Aiden Hollander/Aiden_Hollander_2024-04-13_16-35-57.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df2 = pd.read_csv(mount_aloysius_aiden, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df2.columns = df2.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df2.head(), df2.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00        91           NaN            NaN      NaN
#  1          NaN  00:00:02        91           NaN            NaN      NaN
#  2          NaN  00:00:04        91           NaN            NaN      NaN
#  3          NaN  00:00:06        92           NaN            NaN      NaN
#  4          NaN  00:00:08        92           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
#  2        NaN          NaN
#  3        NaN          NaN
#  4        NaN          NaN  ,
#  Index(['Sample rate', 'Time', 'HR (bpm)', 'Speed (mi/h)', 'Pace (min/mi)',
#         'Cadence', 'Altitude (ft)', 'Stride length (in)', 'Distances (ft)',
#         'Temperatures (F)', 'Power (W)', 'Unnamed: 11'],
#        dtype='object'))

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Mount Aloysius Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df2, df3]
titles = [
    "Aiden Hollander"
]
plot_multiple_time_series(dfs, titles)

# %%
saint_vincent_aiden = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Aiden Hollander/Aiden_Hollander_2024-04-13_17-44-54.CSV'
saint_vincent_jonathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Goalies/Jonathan Leary/Jonathan+_Leary_2024-04-13_17-44-45.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df2 = pd.read_csv(saint_vincent_aiden, skiprows=2)
df3 = pd.read_csv(saint_vincent_jonathan, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00        77           NaN            NaN      NaN
#  1          NaN  00:00:02        77           NaN            NaN      NaN
#  2          NaN  00:00:04        77           NaN            NaN      NaN
#  3          NaN  00:00:06        77           NaN            NaN      NaN
#  4          NaN  00:00:08        76           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
#  2        NaN          NaN
#  3        NaN          NaN
#  4        NaN          NaN  ,
#  Index(['Sample rate', 'Time', 'HR (bpm)', 'Speed (mi/h)', 'Pace (min/mi)',
#         'Cadence', 'Altitude (ft)', 'Stride length (in)', 'Distances (ft)',
#         'Temperatures (F)', 'Power (W)', 'Unnamed: 11'],
#        dtype='object'))

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Saint Vincent Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df2, df3]
titles = [
    "Aiden Hollander",
    "Jonathan Leary"
]
plot_multiple_time_series(dfs, titles)
