# %%
#**************************************
# Name: Jonah Zembower
# Date: June 28, 2024
# Focusing in on positional differences
#**************************************

# %%
# import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing file paths
aaron_spisak = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Aaron Spisak/Aaron_Spisak_Spring_2024.csv")
alejandro = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Alejandro Lazo Pacheco/Alejandro_Lazo_Pacheco_Spring_2024.csv")
ben_nicholson = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Ben Nicholson/Ben_Nicholson_Spring_2024.csv")
brandon_knapp = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Brandon Knapp/Brandon_Knapp_Spring_2024.csv")
joey_lemansky = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Joey Lemansky/Joey_Lemansky_Spring_2024.csv")
nadeem_alokla = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Nadeem Alokla/Nadeem_Alokla_Spring_2024.csv")
nathan_russell = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Nathan Russell/Nathan_Russell_Spring_2024.csv")
sebastian_acuna = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Sebastian Acuna/Sebastian_Acuna_Spring_2024.csv")
stanislav_chernyshov = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Stanislav Chernyshov/Stanislav_Chernyshov_Spring_2024.csv")
zackary_redden = pd.read_csv("/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Zackary Redden/Zackary_Redden_Spring_2024.csv")

# %%
# Calculate the daily average heart rates for each person
aaron_daily_avg = aaron_spisak.mean(axis=0)
alejandro_daily_avg = alejandro.mean(axis=0)
ben_daily_avg = ben_nicholson.mean(axis=0)
brandon_daily_avg = brandon_knapp.mean(axis=0)
joey_daily_avg = joey_lemansky.mean(axis=0)
nadeem_daily_avg = nadeem_alokla.mean(axis=0)
nathan_daily_avg = nathan_russell.mean(axis=0)
sebastian_daily_avg = sebastian_acuna.mean(axis=0)
stanislav_daily_avg = stanislav_chernyshov.mean(axis=0)
zackary_daily_avg = zackary_redden.mean(axis=0)


# Convert the indices to datetime for plotting
aaron_daily_avg.index = pd.to_datetime(aaron_daily_avg.index)
alejandro_daily_avg.index = pd.to_datetime(alejandro_daily_avg.index)
ben_daily_avg.index = pd.to_datetime(ben_daily_avg.index)
brandon_daily_avg.index = pd.to_datetime(brandon_daily_avg.index)
joey_daily_avg.index = pd.to_datetime(joey_daily_avg.index)
nadeem_daily_avg.index = pd.to_datetime(nadeem_daily_avg.index)
nathan_daily_avg.index = pd.to_datetime(nathan_daily_avg.index)
sebastian_daily_avg.index = pd.to_datetime(sebastian_daily_avg.index)
stanislav_daily_avg.index = pd.to_datetime(stanislav_daily_avg.index)
zackary_daily_avg.index = pd.to_datetime(zackary_daily_avg.index)

# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Aaron': aaron_daily_avg,
    'Alejandro': alejandro_daily_avg,
    'Ben': ben_daily_avg,
    'Brandon': brandon_daily_avg,
    'Joey': joey_daily_avg,
    'Nadeem': nadeem_daily_avg,
    'Nathan': nathan_daily_avg,
    'Sebastian': sebastian_daily_avg,
    'Stanislav': stanislav_daily_avg,
    'Zackary': zackary_daily_avg
})

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Calculate the daily average heart rates for each person
aaron_daily_avg = aaron_spisak.mean(axis=0)
alejandro_daily_avg = alejandro.mean(axis=0)
ben_daily_avg = ben_nicholson.mean(axis=0)
brandon_daily_avg = brandon_knapp.mean(axis=0)
joey_daily_avg = joey_lemansky.mean(axis=0)
nadeem_daily_avg = nadeem_alokla.mean(axis=0)
nathan_daily_avg = nathan_russell.mean(axis=0)
sebastian_daily_avg = sebastian_acuna.mean(axis=0)
stanislav_daily_avg = stanislav_chernyshov.mean(axis=0)
zackary_daily_avg = zackary_redden.mean(axis=0)


# Convert the indices to datetime for plotting
aaron_daily_avg.index = pd.to_datetime(aaron_daily_avg.index)
alejandro_daily_avg.index = pd.to_datetime(alejandro_daily_avg.index)
ben_daily_avg.index = pd.to_datetime(ben_daily_avg.index)
brandon_daily_avg.index = pd.to_datetime(brandon_daily_avg.index)
joey_daily_avg.index = pd.to_datetime(joey_daily_avg.index)
nadeem_daily_avg.index = pd.to_datetime(nadeem_daily_avg.index)
nathan_daily_avg.index = pd.to_datetime(nathan_daily_avg.index)
sebastian_daily_avg.index = pd.to_datetime(sebastian_daily_avg.index)
stanislav_daily_avg.index = pd.to_datetime(stanislav_daily_avg.index)
zackary_daily_avg.index = pd.to_datetime(zackary_daily_avg.index)

# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Aaron': aaron_daily_avg,
    'Alejandro': alejandro_daily_avg,
    'Ben': ben_daily_avg,
    'Brandon': brandon_daily_avg,
    'Joey': joey_daily_avg,
    'Nadeem': nadeem_daily_avg,
    'Nathan': nathan_daily_avg,
    'Sebastian': sebastian_daily_avg,
    'Stanislav': stanislav_daily_avg,
    'Zackary': zackary_daily_avg
})

# Calculate the overall average across all players
comparison_df['Average'] = comparison_df.mean(axis=1)

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

# Highlight the average line
plt.plot(comparison_df.index, comparison_df['Average'], label='Average', color='black', linestyle='--', linewidth=2)

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Compute and output the overall average heart rate across all sessions for each player
aaron_overall_avg = aaron_daily_avg.mean()
alejandro_overall_avg = alejandro_daily_avg.mean()
ben_overall_avg = ben_daily_avg.mean()
brandon_overall_avg = brandon_daily_avg.mean()
joey_overall_avg = joey_daily_avg.mean()
nadeem_overall_avg = nadeem_daily_avg.mean()
nathan_overall_avg = nathan_daily_avg.mean()
sebastian_overall_avg = sebastian_daily_avg.mean()
stanislav_overall_avg = stanislav_daily_avg.mean()
zackary_overall_avg = zackary_daily_avg.mean()

# Compute the overall average heart rate across all players
overall_avg_all_players = comparison_df['Average'].mean()

# Output the results
print(f"Overall average heart rate for Aaron: {aaron_overall_avg:.2f}")
print(f"Overall average heart rate for Alejandro: {alejandro_overall_avg:.2f}")
print(f"Overall average heart rate for Ben: {ben_overall_avg:.2f}")
print(f"Overall average heart rate for Brandon: {brandon_overall_avg:.2f}")
print(f"Overall average heart rate for Joey: {joey_overall_avg:.2f}")
print(f"Overall average heart rate for Nadeem: {nadeem_overall_avg:.2f}")
print(f"Overall average heart rate for Nathan: {nathan_overall_avg:.2f}")
print(f"Overall average heart rate for Sebastian: {sebastian_overall_avg:.2f}")
print(f"Overall average heart rate for Stanislav: {stanislav_overall_avg:.2f}")
print(f"Overall average heart rate for Zackary: {zackary_overall_avg:.2f}")
print(f"Overall average heart rate across all players: {overall_avg_all_players:.2f}")
# Out:
# Overall average heart rate for Aaron: 145.38
# Overall average heart rate for Alejandro: 142.12
# Overall average heart rate for Ben: 129.77
# Overall average heart rate for Brandon: 147.09
# Overall average heart rate for Joey: 157.21
# Overall average heart rate for Nadeem: 141.66
# Overall average heart rate for Nathan: 140.89
# Overall average heart rate for Sebastian: 128.24
# Overall average heart rate for Stanislav: 143.62
# Overall average heart rate for Zackary: 138.62
# Overall average heart rate across all players: 142.57

# %% [markdown]
# Now let's look at the weekly average for each player developing an interesting comparison.

# %%
# Convert the index to datetime for resampling
comparison_df.index = pd.to_datetime(comparison_df.index)

# Resample the data by week and calculate the weekly average heart rate for each individual
weekly_avg_df = comparison_df.resample('W').mean()

# Plot the weekly average heart rates
plt.figure(figsize=(14, 8))

for column in weekly_avg_df.columns:
    plt.plot(weekly_avg_df.index, weekly_avg_df[column], label=column, marker='o')

plt.xlabel('Week')
plt.ylabel('Average Heart Rate')
plt.title('Weekly Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Reset index to get dates in the DataFrame
comparison_df.reset_index(inplace=True)

# Convert DataFrame from wide to long format for easier plotting
long_df = comparison_df.melt(id_vars='index', var_name='Individual', value_name='Heart Rate')

# Add a column for week
long_df['Week'] = pd.to_datetime(long_df['index']).dt.to_period('W')

# Plot box plots
plt.figure(figsize=(16, 10))
sns.boxplot(x='Week', y='Heart Rate', hue='Individual', data=long_df, palette='Set3')
plt.title('Weekly Distribution of Heart Rates')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Generate heatmaps to visualize the intensity of heart rates over time

# Set the index back to the original datetime index
comparison_df.set_index('index', inplace=True)

# Plot heatmaps
plt.figure(figsize=(16, 12))

sns.heatmap(comparison_df.T, cmap='coolwarm', cbar=True, linewidths=.5)
plt.title('Heatmap of Heart Rate Intensities Over Time')
plt.xlabel('Date')
plt.ylabel('Individual')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plot a correlation matrix to explore relationships between heart rates of different individuals
correlation_matrix = comparison_df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Heart Rates Between Individuals')
plt.tight_layout()
plt.show()

# %%
# Calculate the daily average heart rates for each person
aaron_daily_max = aaron_spisak.max(axis=0)
alejandro_daily_max = alejandro.max(axis=0)
ben_daily_max = ben_nicholson.max(axis=0)
brandon_daily_max = brandon_knapp.max(axis=0)
joey_daily_max = joey_lemansky.max(axis=0)
nadeem_daily_max = nadeem_alokla.max(axis=0)
nathan_daily_max = nathan_russell.max(axis=0)
sebastian_daily_max = sebastian_acuna.max(axis=0)
stanislav_daily_max = stanislav_chernyshov.max(axis=0)
zackary_daily_max = zackary_redden.max(axis=0)


# Convert the indices to datetime for plotting
aaron_daily_max.index = pd.to_datetime(aaron_daily_max.index)
alejandro_daily_max.index = pd.to_datetime(alejandro_daily_max.index)
ben_daily_max.index = pd.to_datetime(ben_daily_max.index)
brandon_daily_max.index = pd.to_datetime(brandon_daily_max.index)
joey_daily_max.index = pd.to_datetime(joey_daily_max.index)
nadeem_daily_max.index = pd.to_datetime(nadeem_daily_max.index)
nathan_daily_max.index = pd.to_datetime(nathan_daily_max.index)
sebastian_daily_max.index = pd.to_datetime(sebastian_daily_max.index)
stanislav_daily_max.index = pd.to_datetime(stanislav_daily_max.index)
zackary_daily_max.index = pd.to_datetime(zackary_daily_max.index)

# Create a DataFrame for easier comparison
comparison_df_max = pd.DataFrame({
    'Aaron': aaron_daily_max,
    'Alejandro': alejandro_daily_max,
    'Ben': ben_daily_max,
    'Brandon': brandon_daily_max,
    'Joey': joey_daily_max,
    'Nadeem': nadeem_daily_max,
    'Nathan': nathan_daily_max,
    'Sebastian': sebastian_daily_max,
    'Stanislav': stanislav_daily_max,
    'Zackary': zackary_daily_max
})

# Plot the maximum heart rate for each day
plt.figure(figsize=(14, 8))
for column in comparison_df_max.columns:
    plt.plot(comparison_df_max.index, comparison_df_max[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Maximum Heart Rate')
plt.title('Maximum Heart Rate for Each Day Across All Individuals')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# Now I want to look at the moments leading up to a game and how players are reacting in their heart rate.
#
# We had games on:
# - March 16 Game against Missisauga
# - March 24 Game against Lancaster F.C.
# - April 7 Game against Wheeling University
# - April 13 Tournament against Juniata, Mount Aloysius, then St. Vincent

# %%
missisauga_aaron = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Aaron Spisak/Aaron_Spisak_2024-03-16_15-24-14.CSV'
missisauga_alejandro = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Alejandro Lazo-Pacheco/Alejandro+_Lazo-Pacheco_2024-03-16_15-24-13.CSV'
missisauga_ben = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Ben Nicholson/Ben_Nicholson_2024-03-16_15-24-15.CSV'
missisauga_brandon = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Brandon Knapp/Brandon_Knapp_2024-03-16_15-24-17.CSV'
missisauga_joey = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Joey Lemansky/Joey_Lemansky_2024-03-16_15-24-13.CSV'
missisauga_nadeem = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nadeem Al-Okla/Nadeem_Al-Okla_2024-03-16_15-24-13.CSV'
missisauga_nathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nathan Russell/Nathan_Russell_2024-03-16_15-24-13.CSV'
missisauga_sebastian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Sebastian Acuna/Sebastian_Acuna_2024-03-16_15-24-13.CSV'
missisauga_stanislav = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Stanislav Chernyshov/Stas_Chernyshov_2024-03-16_15-24-13.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(missisauga_aaron, skiprows=2)
df2 = pd.read_csv(missisauga_alejandro, skiprows=2)
df3 = pd.read_csv(missisauga_ben, skiprows=2)
df4 = pd.read_csv(missisauga_brandon, skiprows=2)
df5 = pd.read_csv(missisauga_joey, skiprows=2)
df6 = pd.read_csv(missisauga_nadeem, skiprows=2)
df7 = pd.read_csv(missisauga_nathan, skiprows=2)
df8 = pd.read_csv(missisauga_sebastian, skiprows=2)
df9 = pd.read_csv(missisauga_stanislav, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()
df7.columns = df7.columns.str.strip()
df8.columns = df8.columns.str.strip()
df9.columns = df9.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
df7.head(), df7.columns
df8.head(), df8.columns
df9.head(), df9.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       135           NaN            NaN      NaN
#  1          NaN  00:00:02       134           NaN            NaN      NaN
#  2          NaN  00:00:04       135           NaN            NaN      NaN
#  3          NaN  00:00:06       137           NaN            NaN      NaN
#  4          NaN  00:00:08       138           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Missisauga Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3, df4]
titles = [
    "Aaron Spisak",
    "Alejandro Lazo Pacheco",
    "Ben Nicholson",
    "Brandon Knapp"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Missisuaga Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df5, df6, df7, df8, df9]
titles = [
    "Joey Lemansky",
    "Nadeem Al-Okla",
    "Natahn Russell",
    "Sebastian Acuna",
    "Stanislav Chernyshov"
]
plot_multiple_time_series(dfs, titles)

# %%
lancaster_ben = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Ben Nicholson/Ben_Nicholson_2024-03-24_14-27-35.CSV'
lancaster_brandon = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Brandon Knapp/Brandon_Knapp_2024-03-24_14-27-34.CSV'
lancaster_joey = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Joey Lemansky/Joey_Lemansky_2024-03-24_14-27-24.CSV'
lancaster_nadeem = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nadeem Al-Okla/Nadeem_Al-Okla_2024-03-24_14-27-24.CSV'
lancaster_sebastian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Sebastian Acuna/Sebastian_Acuna_2024-03-24_14-27-24.CSV'
lancaster_stanislav = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Stanislav Chernyshov/Stas_Chernyshov_2024-03-24_14-27-27.CSV'
lancaster_zackary = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Zackary Redden/Zackary_Redden_2024-03-24_15-11-59.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(lancaster_ben, skiprows=2)
df2 = pd.read_csv(lancaster_brandon, skiprows=2)
df3 = pd.read_csv(lancaster_joey, skiprows=2)
df4 = pd.read_csv(lancaster_nadeem, skiprows=2)
df5 = pd.read_csv(lancaster_sebastian, skiprows=2)
df6 = pd.read_csv(lancaster_stanislav, skiprows=2)
df7 = pd.read_csv(lancaster_zackary, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()
df7.columns = df7.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
df7.head(), df7.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       184           NaN            NaN      NaN
#  1          NaN  00:00:02       185           NaN            NaN      NaN
#  2          NaN  00:00:04       185           NaN            NaN      NaN
#  3          NaN  00:00:06       185           NaN            NaN      NaN
#  4          NaN  00:00:08       183           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Lancaster F.C. Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3, df4]
titles = [
    "Ben Nicholson",
    "Brandon Knapp",
    "Joey Lemansky",
    "Nadeem Al-Okla"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Lancaster F.C. Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df5, df6, df7]
titles = [
    "Sebastian Acuna",
    "Stanislav Chernyshov",
    "Zackary Redden"
]
plot_multiple_time_series(dfs, titles)

# %%
wheeling_aaron = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Aaron Spisak/Aaron_Spisak_2024-04-07_14-54-48.CSV'
wheeling_alejandro = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Alejandro Lazo-Pacheco/Alejandro+_Lazo-Pacheco_2024-04-07_14-54-16.CSV'
wheeling_brandon = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Brandon Knapp/Brandon_Knapp_2024-04-07_14-54-17.CSV'
wheeling_joey = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Joey Lemansky/Joey_Lemansky_2024-04-07_14-54-17.CSV'
wheeling_nadeem = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nadeem Al-Okla/Nadeem_Al-Okla_2024-04-07_14-54-17.CSV'
wheeling_nathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nathan Russell/Nathan_Russell_2024-04-07_14-54-17.CSV'
wheeling_sebastian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Sebastian Acuna/Sebastian_Acuna_2024-04-07_16-04-25.CSV'
wheeling_stanislav = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Stanislav Chernyshov/Stas_Chernyshov_2024-04-07_16-08-43.CSV'
wheeling_zackary = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Zackary Redden/Zackary_Redden_2024-04-07_16-06-30.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(wheeling_aaron, skiprows=2)
df2 = pd.read_csv(wheeling_alejandro, skiprows=2)
df3 = pd.read_csv(wheeling_brandon, skiprows=2)
df4 = pd.read_csv(wheeling_joey, skiprows=2)
df5 = pd.read_csv(wheeling_nadeem, skiprows=2)
df6 = pd.read_csv(wheeling_nathan, skiprows=2)
df7 = pd.read_csv(wheeling_sebastian, skiprows=2)
df8 = pd.read_csv(wheeling_stanislav, skiprows=2)
df9 = pd.read_csv(wheeling_zackary, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()
df7.columns = df7.columns.str.strip()
df8.columns = df8.columns.str.strip()
df9.columns = df9.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
df7.head(), df7.columns
df8.head(), df8.columns
df9.head(), df9.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       127           NaN            NaN      NaN
#  1          NaN  00:00:02       126           NaN            NaN      NaN
#  2          NaN  00:00:04       125           NaN            NaN      NaN
#  3          NaN  00:00:06       126           NaN            NaN      NaN
#  4          NaN  00:00:08       129           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3, df4]
titles = [
    "Aaron Spisak",
    "Alejandro Lazo Pacheco",
    "Brandon Knapp",
    "Joey Lemansky"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df5, df6, df7]
titles = [
    "Nadeem Al-Okla",
    "Nathan Russell",
    "Sebastian Acuna"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df8, df9]
titles = [
    "Stanislav Chernyshov",
    "Zackary Redden"
]
plot_multiple_time_series(dfs, titles)

# %%
juniata_aaron = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Aaron Spisak/Aaron_Spisak_2024-04-13_15-02-30.CSV'
juniata_alejandro = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Alejandro Lazo-Pacheco/Alejandro+_Lazo-Pacheco_2024-04-13_15-02-30.CSV'
juniata_joey = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Joey Lemansky/Joey_Lemansky_2024-04-13_15-02-30.CSV'
juniata_nadeem = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nadeem Al-Okla/Nadeem_Al-Okla_2024-04-13_15-02-30.CSV'
juniata_nathan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nathan Russell/Nathan_Russell_2024-04-13_15-02-30.CSV'
juniata_sebastian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Sebastian Acuna/Sebastian_Acuna_2024-04-13_15-02-30.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(juniata_aaron, skiprows=2)
df2 = pd.read_csv(juniata_alejandro, skiprows=2)
df3 = pd.read_csv(juniata_joey, skiprows=2)
df4 = pd.read_csv(juniata_nadeem, skiprows=2)
df5 = pd.read_csv(juniata_nathan, skiprows=2)
df6 = pd.read_csv(juniata_sebastian, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       100           NaN            NaN      NaN
#  1          NaN  00:00:02        97           NaN            NaN      NaN
#  2          NaN  00:00:04        97           NaN            NaN      NaN
#  3          NaN  00:00:06        97           NaN            NaN      NaN
#  4          NaN  00:00:08        96           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Juniata Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Aaron Spisak",
    "Alejandro Lazo Pacheco",
    "Joey Lemansky"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Juniata Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df4, df5, df6]
titles = [
    "Nadeem Al-Okla",
    "Nathan Russell",
    "Sebastian Acuna"
]
plot_multiple_time_series(dfs, titles)

# %%
mount_aloysius_alejandro = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Alejandro Lazo-Pacheco/Alejandro+_Lazo-Pacheco_2024-04-13_16-53-35.CSV'
mount_aloysius_nadeem = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Nadeem Al-Okla/Nadeem_Al-Okla_2024-04-13_16-35-57.CSV'
mount_aloysius_sebastian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Sebastian Acuna/Sebastian_Acuna_2024-04-13_16-37-07.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(mount_aloysius_alejandro, skiprows=2)
df2 = pd.read_csv(mount_aloysius_nadeem, skiprows=2)
df3 = pd.read_csv(mount_aloysius_sebastian, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       147           NaN            NaN      NaN
#  1          NaN  00:00:02       147           NaN            NaN      NaN
#  2          NaN  00:00:04       147           NaN            NaN      NaN
#  3          NaN  00:00:06       147           NaN            NaN      NaN
#  4          NaN  00:00:08       147           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Mount Aloysius Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Alejandro Lazo Pacheco",
    "Nadeem Al-Okla",
    "Sebastian Acuna"
]
plot_multiple_time_series(dfs, titles)

# %%
saint_vincent_brandon = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Brandon Knapp/Brandon_Knapp_2024-04-13_17-44-45.CSV'
saint_vincent_sebastian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Sebastian Acuna/Sebastian_Acuna_2024-04-13_17-44-45.CSV'
saint_vincent_stanislav = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Stanislav Chernyshov/Stas_Chernyshov_2024-04-13_17-44-45.CSV'
saint_vincent_zackary = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Outside Backs/Zackary Redden/Zackary_Redden_2024-04-13_17-45-16.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(saint_vincent_brandon, skiprows=2)
df2 = pd.read_csv(saint_vincent_sebastian, skiprows=2)
df3 = pd.read_csv(saint_vincent_stanislav, skiprows=2)
df4 = pd.read_csv(saint_vincent_zackary, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       146           NaN            NaN      NaN
#  1          NaN  00:00:02       146           NaN            NaN      NaN
#  2          NaN  00:00:04       146           NaN            NaN      NaN
#  3          NaN  00:00:06       146           NaN            NaN      NaN
#  4          NaN  00:00:08       146           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Saint Vincent Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3, df4]
titles = [
    "Brandon Knapp",
    "Sebastian Acuna",
    "Stanislav Chernyshov",
    "Zackary Redden"
]
plot_multiple_time_series(dfs, titles)
