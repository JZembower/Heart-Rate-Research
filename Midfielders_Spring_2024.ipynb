# %%
#**************************************
# Name: Jonah Zembower
# Date: June 28, 2024
# Focusing in on positional differences
#**************************************

# %%
# import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing file paths
ethan_opiela = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Ethan Opiela/Ethan_Opiela_Spring_2024.csv')
jayson_mcgaffin = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Jayson Mcgaffin/Jayson Mcgaffin_Spring_2024.csv')
joseph_lauer = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Joseph Lauer/Joseph_Lauer_Spring_2024.csv')
julian_marker = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Julian Marker/Julian_Marker_Spring_2024.csv')
nevlyn_harper = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Nevlyn Harper/Nevlyn_Harper_Spring_2024.csv')
nico_morello = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Nico Morello/Nico_Morello_Spring_2024.csv')
oscar_heggem = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Oscar Heggem/Oscar_Heggem_Spring_2024.csv')
vasilis_christodoulou = pd.read_csv('/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Coding Applications/Heart_Rate_Research/Individual Heart Rate/Vasilis Christodoulou/Vasilis_Christodoulou_Spring_2024.csv')

# %%
# Calculate the daily average heart rates for each person
ethan_daily_avg = ethan_opiela.mean(axis=0)
jayson_daily_avg = jayson_mcgaffin.mean(axis=0)
joseph_daily_avg = joseph_lauer.mean(axis=0)
julian_daily_avg = julian_marker.mean(axis=0)
nevlyn_daily_avg = nevlyn_harper.mean(axis=0)
nico_daily_avg = nico_morello.mean(axis=0)
oscar_daily_avg = oscar_heggem.mean(axis=0)
vasilis_daily_avg = vasilis_christodoulou.mean(axis=0)


# Convert the indices to datetime for plotting
ethan_daily_avg.index = pd.to_datetime(ethan_daily_avg.index)
jayson_daily_avg.index = pd.to_datetime(jayson_daily_avg.index)
joseph_daily_avg.index = pd.to_datetime(joseph_daily_avg.index)
julian_daily_avg.index = pd.to_datetime(julian_daily_avg.index)
nevlyn_daily_avg.index = pd.to_datetime(nevlyn_daily_avg.index)
nico_daily_avg.index = pd.to_datetime(nico_daily_avg.index)
oscar_daily_avg.index = pd.to_datetime(oscar_daily_avg.index)
vasilis_daily_avg.index = pd.to_datetime(vasilis_daily_avg.index)


# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Ethan': ethan_daily_avg,
    'Jayson': jayson_daily_avg,
    'Joseph': joseph_daily_avg,
    'Julian': julian_daily_avg,
    'Nevlyn': nevlyn_daily_avg,
    'Nico': nico_daily_avg,
    'Oscar': oscar_daily_avg,
    'Vasilis': vasilis_daily_avg
})

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Calculate the daily average heart rates for each person
ethan_daily_avg = ethan_opiela.mean(axis=0)
jayson_daily_avg = jayson_mcgaffin.mean(axis=0)
joseph_daily_avg = joseph_lauer.mean(axis=0)
julian_daily_avg = julian_marker.mean(axis=0)
nevlyn_daily_avg = nevlyn_harper.mean(axis=0)
nico_daily_avg = nico_morello.mean(axis=0)
oscar_daily_avg = oscar_heggem.mean(axis=0)
vasilis_daily_avg = vasilis_christodoulou.mean(axis=0)


# Convert the indices to datetime for plotting
ethan_daily_avg.index = pd.to_datetime(ethan_daily_avg.index)
jayson_daily_avg.index = pd.to_datetime(jayson_daily_avg.index)
joseph_daily_avg.index = pd.to_datetime(joseph_daily_avg.index)
julian_daily_avg.index = pd.to_datetime(julian_daily_avg.index)
nevlyn_daily_avg.index = pd.to_datetime(nevlyn_daily_avg.index)
nico_daily_avg.index = pd.to_datetime(nico_daily_avg.index)
oscar_daily_avg.index = pd.to_datetime(oscar_daily_avg.index)
vasilis_daily_avg.index = pd.to_datetime(vasilis_daily_avg.index)


# Create a DataFrame for easier comparison
comparison_df = pd.DataFrame({
    'Ethan': ethan_daily_avg,
    'Jayson': jayson_daily_avg,
    'Joseph': joseph_daily_avg,
    'Julian': julian_daily_avg,
    'Nevlyn': nevlyn_daily_avg,
    'Nico': nico_daily_avg,
    'Oscar': oscar_daily_avg,
    'Vasilis': vasilis_daily_avg
})

# Calculate the overall average across all players
comparison_df['Average'] = comparison_df.mean(axis=1)

# Plot the data
plt.figure(figsize=(14, 8))

for column in comparison_df.columns:
    plt.plot(comparison_df.index, comparison_df[column], label=column, marker='o')

# Highlight the average line
plt.plot(comparison_df.index, comparison_df['Average'], label='Average', color='black', linestyle='--', linewidth=2)

plt.xlabel('Date')
plt.ylabel('Average Heart Rate')
plt.title('Daily Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Compute and output the overall average heart rate across all sessions for each player
ethan_overall_avg = ethan_daily_avg.mean()
jayson_overall_avg = jayson_daily_avg.mean()
joseph_overall_avg = joseph_daily_avg.mean()
julian_overall_avg = julian_daily_avg.mean()
nevlyn_overall_avg = nevlyn_daily_avg.mean()
nico_overall_avg = nico_daily_avg.mean()
oscar_overall_avg = oscar_daily_avg.mean()
vasilis_overall_avg = vasilis_daily_avg.mean()

# Compute the overall average heart rate across all players
overall_avg_all_players = comparison_df['Average'].mean()

# Output the results
print(f"Overall average heart rate for Ethan: {ethan_overall_avg:.2f}")
print(f"Overall average heart rate for Jayson: {jayson_overall_avg:.2f}")
print(f"Overall average heart rate for Joseph: {joseph_overall_avg:.2f}")
print(f"Overall average heart rate for Julian: {julian_overall_avg:.2f}")
print(f"Overall average heart rate for Nevlyn: {nevlyn_overall_avg:.2f}")
print(f"Overall average heart rate for Nico: {nico_overall_avg:.2f}")
print(f"Overall average heart rate for Oscar: {oscar_overall_avg:.2f}")
print(f"Overall average heart rate for Vasilis: {vasilis_overall_avg:.2f}")
print(f"Overall average heart rate across all players: {overall_avg_all_players:.2f}")
# Out:
# Overall average heart rate for Ethan: 147.32
# Overall average heart rate for Jayson: 133.53
# Overall average heart rate for Joseph: 149.04
# Overall average heart rate for Julian: 133.83
# Overall average heart rate for Nevlyn: 140.43
# Overall average heart rate for Nico: 142.87
# Overall average heart rate for Oscar: 140.88
# Overall average heart rate for Vasilis: 137.07
# Overall average heart rate across all players: 141.18

# %%
# Convert the index to datetime for resampling
comparison_df.index = pd.to_datetime(comparison_df.index)

# Resample the data by week and calculate the weekly average heart rate for each individual
weekly_avg_df = comparison_df.resample('W').mean()

# Plot the weekly average heart rates
plt.figure(figsize=(14, 8))

for column in weekly_avg_df.columns:
    plt.plot(weekly_avg_df.index, weekly_avg_df[column], label=column, marker='o')

plt.xlabel('Week')
plt.ylabel('Average Heart Rate')
plt.title('Weekly Average Heart Rate Comparison')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
# Reset index to get dates in the DataFrame
comparison_df.reset_index(inplace=True)

# Convert DataFrame from wide to long format for easier plotting
long_df = comparison_df.melt(id_vars='index', var_name='Individual', value_name='Heart Rate')

# Add a column for week
long_df['Week'] = pd.to_datetime(long_df['index']).dt.to_period('W')

# Plot box plots
plt.figure(figsize=(16, 10))
sns.boxplot(x='Week', y='Heart Rate', hue='Individual', data=long_df, palette='Set3')
plt.title('Weekly Distribution of Heart Rates')
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Generate heatmaps to visualize the intensity of heart rates over time

# Set the index back to the original datetime index
comparison_df.set_index('index', inplace=True)

# Plot heatmaps
plt.figure(figsize=(16, 12))

sns.heatmap(comparison_df.T, cmap='coolwarm', cbar=True, linewidths=.5)
plt.title('Heatmap of Heart Rate Intensities Over Time')
plt.xlabel('Date')
plt.ylabel('Individual')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plot a correlation matrix to explore relationships between heart rates of different individuals
correlation_matrix = comparison_df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Heart Rates Between Individuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# Julian appears to be really low for some of his weeks and has no correlation to anyone else. This would be interesting to see why that is.

# %%
# Calculate the daily average heart rates for each person
ethan_daily_max = ethan_opiela.max(axis=0)
jayson_daily_max = jayson_mcgaffin.max(axis=0)
joseph_daily_max = joseph_lauer.max(axis=0)
julian_daily_max = julian_marker.max(axis=0)
nevlyn_daily_max = nevlyn_harper.max(axis=0)
nico_daily_max = nico_morello.max(axis=0)
oscar_daily_max = oscar_heggem.max(axis=0)
vasilis_daily_max = vasilis_christodoulou.max(axis=0)


# Convert the indices to datetime for plotting
ethan_daily_max.index = pd.to_datetime(ethan_daily_max.index)
jayson_daily_max.index = pd.to_datetime(jayson_daily_max.index)
joseph_daily_max.index = pd.to_datetime(joseph_daily_max.index)
julian_daily_max.index = pd.to_datetime(julian_daily_max.index)
nevlyn_daily_max.index = pd.to_datetime(nevlyn_daily_max.index)
nico_daily_max.index = pd.to_datetime(nico_daily_max.index)
oscar_daily_max.index = pd.to_datetime(oscar_daily_max.index)
vasilis_daily_max.index = pd.to_datetime(vasilis_daily_max.index)


# Create a DataFrame for easier comparison
comparison_df_max = pd.DataFrame({
    'Ethan': ethan_daily_max,
    'Jayson': jayson_daily_max,
    'Joseph': joseph_daily_max,
    'Julian': julian_daily_max,
    'Nevlyn': nevlyn_daily_max,
    'Nico': nico_daily_max,
    'Oscar': oscar_daily_max,
    'Vasilis': vasilis_daily_max
})

# Plot the maximum heart rate for each day
plt.figure(figsize=(14, 8))
for column in comparison_df_max.columns:
    plt.plot(comparison_df_max.index, comparison_df_max[column], label=column, marker='o')

plt.xlabel('Date')
plt.ylabel('Maximum Heart Rate')
plt.title('Maximum Heart Rate for Each Day Across All Individuals')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# Now I want to look at the moments leading up to a game and how players are reacting in their heart rate.
#
# We had games on:
# - March 16 Game against Missisauga
# - March 24 Game against Lancaster F.C.
# - April 7 Game against Wheeling University
# - April 13 Tournament against Juniata, Mount Aloysius, then St. Vincent

# %%
missisauga_ethan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Ethan Opiela/Ethan_Opiela_2024-03-16_15-24-13.CSV'
missisauga_joseph = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Joseph Lauer/Joseph_Lauer_2024-03-16_15-24-13.CSV'
missisauga_nevlyn = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Nevlyn Harper/Nevlyn_Harper_2024-03-16_15-24-13.CSV'
missisauga_oscar = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Oscar Heggem/Oscar_Heggem_2024-03-16_15-24-13.CSV'
missisauga_vasilis = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Vasilis Christodoulou/Vasilis_Christodoulou+_2024-03-16_15-24-18.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(missisauga_ethan, skiprows=2)
df2 = pd.read_csv(missisauga_joseph, skiprows=2)
df3 = pd.read_csv(missisauga_nevlyn, skiprows=2)
df4 = pd.read_csv(missisauga_oscar, skiprows=2)
df5 = pd.read_csv(missisauga_vasilis, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       143           NaN            NaN      NaN
#  1          NaN  00:00:02       142           NaN            NaN      NaN
#  2          NaN  00:00:04       142           NaN            NaN      NaN
#  3          NaN  00:00:06       142           NaN            NaN      NaN
#  4          NaN  00:00:08       142           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Missisauga Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Ethan Opiela",
    "Joseph Lauer",
    "Nevlyn Harper"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Missisauga Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df4, df5]
titles = [
    "Oscar Heggem",
    "Vasilis Christodoulou"
]
plot_multiple_time_series(dfs, titles)

# %%
lancaster_ethan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Ethan Opiela/Ethan_Opiela_2024-03-24_14-27-24.CSV'
lancaster_jayson = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Jayson McGaffin/Jayson_McGaffin_2024-03-24_14-27-29.CSV'
lancaster_joseph = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Joseph Lauer/Joseph_Lauer_2024-03-24_14-27-24.CSV'
lancaster_julian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Julian Marker/Julian_Marker_2024-03-24_14-27-25.CSV'
lancaster_nevlyn = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Nevlyn Harper/Nevlyn_Harper_2024-03-24_14-31-50.CSV'
lancaster_oscar = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Oscar Heggem/Oscar_Heggem_2024-03-24_14-27-24.CSV'
lancaster_vasilis = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Vasilis Christodoulou/Vasilis_Christodoulou+_2024-03-24_14-27-26.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(lancaster_ethan, skiprows=2)
df2 = pd.read_csv(lancaster_jayson, skiprows=2)
df3 = pd.read_csv(lancaster_joseph, skiprows=2)
df4 = pd.read_csv(lancaster_julian, skiprows=2)
df5 = pd.read_csv(lancaster_nevlyn, skiprows=2)
df6 = pd.read_csv(lancaster_oscar, skiprows=2)
df7 = pd.read_csv(lancaster_vasilis, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()
df7.columns = df7.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
df7.head(), df7.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       137           NaN            NaN      NaN
#  1          NaN  00:00:02       135           NaN            NaN      NaN
#  2          NaN  00:00:04       136           NaN            NaN      NaN
#  3          NaN  00:00:06       136           NaN            NaN      NaN
#  4          NaN  00:00:08       134           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Lancaster F.C. Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Ethan Opiela",
    "Jayson Mcgaffin",
    "Joseph Lauer"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Lancaster F.C. Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df4, df5, df6, df7]
titles = [
    "Julian Marker",
    "Nevlyn Harper",
    "Oscar Heggem",
    "Vasilis Christodoulou"
]
plot_multiple_time_series(dfs, titles)

# %%
wheeling_ethan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Ethan Opiela/Ethan_Opiela_2024-04-07_14-54-17.CSV'
wheeling_jayson = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Jayson McGaffin/Jayson_McGaffin_2024-04-07_14-54-17.CSV'
wheeling_joseph = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Joseph Lauer/Joseph_Lauer_2024-04-07_14-54-42.CSV'
wheeling_julian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Julian Marker/Julian_Marker_2024-04-07_16-05-13.CSV'
wheeling_nevlyn = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Nevlyn Harper/Nevlyn_Harper_2024-04-07_14-54-17.CSV'
wheeling_nico = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Nico Morrelo/Nico+_Morello_2024-04-07_14-54-31.CSV'
wheeling_oscar = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Oscar Heggem/Oscar_Heggem_2024-04-07_16-09-09.CSV'
wheeling_vasilis = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Vasilis Christodoulou/Vasilis_Christodoulou+_2024-04-07_16-06-51.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(wheeling_ethan, skiprows=2)
df2 = pd.read_csv(wheeling_jayson, skiprows=2)
df3 = pd.read_csv(wheeling_joseph, skiprows=2)
df4 = pd.read_csv(wheeling_julian, skiprows=2)
df5 = pd.read_csv(wheeling_nevlyn, skiprows=2)
df6 = pd.read_csv(wheeling_nico, skiprows=2)
df7 = pd.read_csv(wheeling_oscar, skiprows=2)
df8 = pd.read_csv(wheeling_vasilis, skiprows=2)

# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()
df6.columns = df6.columns.str.strip()
df7.columns = df7.columns.str.strip()
df8.columns = df8.columns.str.strip()

# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
df6.head(), df6.columns
df7.head(), df7.columns
df8.head(), df8.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       123           NaN            NaN      NaN
#  1          NaN  00:00:02       123           NaN            NaN      NaN
#  2          NaN  00:00:04       123           NaN            NaN      NaN
#  3          NaN  00:00:06       123           NaN            NaN      NaN
#  4          NaN  00:00:08       123           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3, df4]
titles = [
    "Ethan Opiela",
    "Jayson Mcgaffin",
    "Joseph Lauer",
    "Julian Marker"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Wheeling Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df5, df6, df7, df8]
titles = [
    "Nevlyn Harper",
    "Nico Morello",
    "Oscar Heggem",
    "Vasilis Christodoulou"
]
plot_multiple_time_series(dfs, titles)

# %%
juniata_jayson = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Jayson McGaffin/Jayson_McGaffin_2024-04-13_15-02-30.CSV'
juniata_joseph = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Joseph Lauer/Joseph_Lauer_2024-04-13_15-02-30.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(juniata_jayson, skiprows=2)
df2 = pd.read_csv(juniata_joseph, skiprows=2)


# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()


# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       125           NaN            NaN      NaN
#  1          NaN  00:00:02       127           NaN            NaN      NaN
#  2          NaN  00:00:04       127           NaN            NaN      NaN
#  3          NaN  00:00:06       124           NaN            NaN      NaN
#  4          NaN  00:00:08       123           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Juniata Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2]
titles = [
    "Jayson Mcgaffin",
    "Joseph Lauer"
]
plot_multiple_time_series(dfs, titles)

# %%
mount_aloysius_ethan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Ethan Opiela/Ethan_Opiela_2024-04-13_16-35-57.CSV'
mount_aloysius_jayson = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Jayson McGaffin/Jayson_McGaffin_2024-04-13_16-35-57.CSV'
mount_aloysius_nevlyn = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Nevlyn Harper/Nevlyn_Harper_2024-04-13_16-36-29.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(mount_aloysius_ethan, skiprows=2)
df2 = pd.read_csv(mount_aloysius_jayson, skiprows=2)
df3 = pd.read_csv(mount_aloysius_nevlyn, skiprows=2)


# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()


# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       158           NaN            NaN      NaN
#  1          NaN  00:00:02       158           NaN            NaN      NaN
#  2          NaN  00:00:04       158           NaN            NaN      NaN
#  3          NaN  00:00:06       158           NaN            NaN      NaN
#  4          NaN  00:00:08       162           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Mount Aloysius Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Ethan Opiela",
    "Jayson Mcgaffin",
    "Nevlyn Harper"
]
plot_multiple_time_series(dfs, titles)

# %%
saint_vincent_ethan = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Ethan Opiela/Ethan_Opiela_2024-04-13_17-44-45.CSV'
saint_vincent_julian = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Julian Marker/Julian_Marker_2024-04-13_17-44-45.CSV'
saint_vincent_nevlyn = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Nevlyn Harper/Nevlyn_Harper_2024-04-13_17-44-45.CSV'
saint_vincent_oscar = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Oscar Heggem/Oscar_Heggem_2024-04-13_17-44-45.CSV'
saint_vincent_vasilis = '/Users/jonahzembower/Library/CloudStorage/OneDrive-SetonHillUniversity/Majors/Heart Rate Monitor Research/Data Analysis/Individual Data/Midfielders/Vasilis Christodoulou/Vasilis_Christodoulou+_2024-04-13_17-44-59.CSV'

# %%
# Reload the data from the correct rows and rename columns for proper access
df1 = pd.read_csv(saint_vincent_ethan, skiprows=2)
df2 = pd.read_csv(saint_vincent_julian, skiprows=2)
df3 = pd.read_csv(saint_vincent_nevlyn, skiprows=2)
df4 = pd.read_csv(saint_vincent_oscar, skiprows=2)
df5 = pd.read_csv(saint_vincent_vasilis, skiprows=2)


# Renaming columns to remove leading/trailing spaces
df1.columns = df1.columns.str.strip()
df2.columns = df2.columns.str.strip()
df3.columns = df3.columns.str.strip()
df4.columns = df4.columns.str.strip()
df5.columns = df5.columns.str.strip()


# Inspect the columns and initial few rows to verify correctness
df1.head(), df1.columns
df2.head(), df2.columns
df3.head(), df3.columns
df4.head(), df4.columns
df5.head(), df5.columns
# Out:
# (   Sample rate      Time  HR (bpm)  Speed (mi/h)  Pace (min/mi)  Cadence  \
#  0          2.0  00:00:00       143           NaN            NaN      NaN
#  1          NaN  00:00:02       143           NaN            NaN      NaN
#  2          NaN  00:00:04       143           NaN            NaN      NaN
#  3          NaN  00:00:06       155           NaN            NaN      NaN
#  4          NaN  00:00:08       158           NaN            NaN      NaN
#
#     Altitude (ft)  Stride length (in)  Distances (ft)  Temperatures (F)  \
#  0            NaN                 NaN             NaN               NaN
#  1            NaN                 NaN             NaN               NaN
#  2            NaN                 NaN             NaN               NaN
#  3            NaN                 NaN             NaN               NaN
#  4            NaN                 NaN             NaN               NaN
#
#     Power (W)  Unnamed: 11
#  0        NaN          NaN
#  1        NaN          NaN
# ...

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Saint Vincent Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df1, df2, df3]
titles = [
    "Ethan Opiela",
    "Julian Marker",
    "Nevlyn Harper"
]
plot_multiple_time_series(dfs, titles)

# %%
# Function to plot multiple time series dataframes on the same graph
def plot_multiple_time_series(dfs, titles):
    plt.figure(figsize=(14, 6))
    
    for df, title in zip(dfs, titles):
        time = pd.to_timedelta(df['Time'])
        hr = pd.to_numeric(df['HR (bpm)'], errors='coerce')
        
        plt.plot(time, hr, label=title)
    
    plt.xlabel('Time')
    plt.ylabel('Heart Rate (bpm)')
    plt.title("Heart Rate Data for Saint Vincent Game")
    plt.legend()
    plt.grid(True)
    plt.show()
# Example usage
dfs = [df4, df5]
titles = [
    "Oscar Heggem",
    "Vasilis Christodoulou"
]
plot_multiple_time_series(dfs, titles)
